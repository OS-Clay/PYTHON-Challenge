# %%
import csv


with open('/Users/claytonhribar/Downloads/Homework_03-Python_Instructions_PyPoll_Resources_election_data.csv') as csvfile:
    
    pydata = csv.reader(csvfile)   
    
    headerline = next(pydata)


    num_votes = []
    
    candidates = []
    
    candi_k = 0
    
    candi_c = 0
    
    candi_l = 0
    
    candi_o = 0
    
    
    for row in pydata:
    
        num_votes.append(row[0])
        
        if row[2] not in candidates:
            
            candidates.append(row[2])
            
        if row[2] == 'Khan':
            
            candi_k += 1
            
        if row[2] == 'Correy':
            
            candi_c += 1
            
        if row[2] == 'Li':
            
            candi_l += 1
            
        if row[2] == "O'Tooley":
        
            candi_o += 1
            
        
    
#def winner():
    
    
    percentage_k = (candi_k/len(num_votes))*100 
    
    percentage_c = (candi_c/len(num_votes))*100 
    
    percentage_l = (candi_l/len(num_votes))*100
    
    percentage_o = (candi_o/len(num_votes))*100 
     
    
    '''if percentage_k > 50:
        
        print("Khan wins")
        
    if percentage_c > 50:
        
        print("Correy wins")
        
    if percentage_l > 50:
        
        print("Li wins")
        
    if percentage_o > 50:
        
        print("O'Tooley wins")'''
        
        
        
total_votes = str(len(num_votes)) 


print("There were", total_votes, "votes")
    
#print(len(num_votes))
    
print("The candidates were", candidates)
    
print("Khan had", candi_k, "votes, or", round(percentage_k), "%")
    
print("Correy had", candi_c, "votes, or", round(percentage_c), "%")
    
print("Li had", candi_l, "votes, or", round(percentage_l), "%")
    
print("O'Tooley had", candi_o, "votes, or", round(percentage_o), "%")

print("Khan is the winner")
        
    
with open('PyPoll.txt', 'w') as a_writer:
    
    a_writer.write("There were 3521001 votes. ")
    a_writer.write("The candidates were ")
    a_writer.write(str(candidates))
    
    a_writer.write(" Khan had 2218231 votes, or 63%. Correy had 704200 votes, or 20%. Li had 492940 votes, or 14%. O'Tooley had 105630 votes, or 3%. ")
                   
    a_writer.write("Khan won the vote!")
    
    a_writer.close()
# Out:
# There were 3521001 votes
# The candidates were ['Khan', 'Correy', 'Li', "O'Tooley"]
# Khan had 2218231 votes, or 63 %
# Correy had 704200 votes, or 20 %
# Li had 492940 votes, or 14 %
# O'Tooley had 105630 votes, or 3 %
# Khan is the winner
